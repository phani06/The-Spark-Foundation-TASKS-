# %% [markdown]
# <h1> PHANINDHAR.T </h1>

# %% [markdown]
# <h2> GRIP-THE SPARK FOUNDATION </h2>

# %% [markdown]
# <h3> TASK3:EXPLORATORY DATA ANALYSIS </h3>

# %% [markdown]
# <h4> IMPORTING LIBRARIES </h4>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
print("The libraries are imported 100%")

# %% [markdown]
# <h4> IMPORTING DATASET </h4>

# %%
df =  pd.read_csv("SampleSuperstore.csv")
print("The dataset has been imported 100%")
# Out:
# The dataset has been imported 100%

# %% [markdown]
# <h4> PRINTING THE FIRST 5 ROWS </h4>

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.nunique(axis=0)
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <h4> CORRELATION MATRIX </h4>

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, 
            cmap=sns.diverging_palette(220, 20, as_cmap=True))

# %%
sns.catplot(x="Segment",y="Profit",data=df,kind='bar',ci=95)

# %%
sns.catplot(x="Ship Mode",y="Profit",data=df,kind='bar',ci=None)

# %%
order = df.groupby(["State"])["Profit"].mean().sort_values().index
sns.catplot(y="State",x="Profit",data=df,kind='bar',ci=None,height=20,order=order)

# %%
sns.catplot(x="Category",y="Profit",data=df,kind="bar",ci=None)

# %%
sns.catplot(x="Category",y="Profit",data=df,kind='bar',ci=None,col="Region")

# %%
plt.subplots(figsize=(8,10))
order=df.groupby(['State'])["State"].count().sort_values().index
sns.countplot(y='State',data=df,order=order)

# %% [markdown]
# <h1> CONCLUSION: </h1>

# %% [markdown]
# <h3> 1. High number of custormers are found in california, Newwork and Texas. Hence these states can be concentrated upon to generate more profit. </h3>

# %% [markdown]
# <h3>2.High profit is genrated with the sales of technology goods,hence sales can be broadened for this category. On the other hand, furniture sales have not generated significant profits  </h3>

# %% [markdown]
# <h3>3.Selling Furtinure in Central region is loss-making <h3>

# %% [markdown]
# <h3>4.Profits among different segment do not vary much </h3>
